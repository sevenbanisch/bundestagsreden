# %%
import json

with open('networkdata.json', 'r') as fp:
    graph = json.load(fp)

# %%
graph
# Out:
# {'directed': False,
#  'graph': 'word_graph',
#  'links': [{'source': 1, 'target': 2, 'weight': 0.1388888888888889},
#   {'source': 1, 'target': 3, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 4, 'weight': 0.08333333333333333},
#   {'source': 1, 'target': 5, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 6, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 7, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 8, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 9, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 10, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 11, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 12, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 13, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 14, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 15, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 16, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 17, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 18, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 19, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 20, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 21, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 22, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 23, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 24, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 25, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 26, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 27, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 28, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 29, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 30, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 31, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 32, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 33, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 34, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 35, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 36, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 37, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 38, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 39, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 40, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 41, 'weight': 0.16666666666666666},
#   {'source': 1, 'target': 42, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 3, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 4, 'weight': 0.08333333333333333},
#   {'source': 2, 'target': 5, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 6, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 7, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 8, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 9, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 10, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 11, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 12, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 13, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 14, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 15, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 16, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 17, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 18, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 19, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 20, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 21, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 22, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 23, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 24, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 25, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 26, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 27, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 28, 'weight': 0.16666666666666666},
#   {'source': 2, 'target': 29, 'weight': 0.16666666666666666},
#   {'source': 3, 'target': 5, 'weight': 0.5},
#   {'source': 3, 'target': 6, 'weight': 0.5},
#   {'source': 3, 'target': 7, 'weight': 0.5},
#   {'source': 4, 'target': 8, 'weight': 0.5},
#   {'source': 4, 'target': 9, 'weight': 0.5},
#   {'source': 4, 'target': 10, 'weight': 0.5},
#   {'source': 4, 'target': 11, 'weight': 0.5},
#   {'source': 4, 'target': 12, 'weight': 0.5},
#   {'source': 5, 'target': 6, 'weight': 1.0},
#   {'source': 8, 'target': 9, 'weight': 1.0},
#   {'source': 8, 'target': 10, 'weight': 1.0},
#   {'source': 8, 'target': 11, 'weight': 1.0},
#   {'source': 8, 'target': 12, 'weight': 1.0},
#   {'source': 9, 'target': 10, 'weight': 1.0},
#   {'source': 9, 'target': 11, 'weight': 1.0},
#   {'source': 9, 'target': 12, 'weight': 1.0},
#   {'source': 10, 'target': 11, 'weight': 1.0},
#   {'source': 10, 'target': 12, 'weight': 1.0},
#   {'source': 11, 'target': 12, 'weight': 1.0},
#   {'source': 13, 'target': 14, 'weight': 1.0},
#   {'source': 13, 'target': 15, 'weight': 1.0},
#   {'source': 13, 'target': 16, 'weight': 1.0},
#   {'source': 13, 'target': 17, 'weight': 1.0},
#   {'source': 13, 'target': 18, 'weight': 1.0},
#   {'source': 13, 'target': 19, 'weight': 1.0},
#   {'source': 14, 'target': 15, 'weight': 1.0},
#   {'source': 14, 'target': 16, 'weight': 1.0},
#   {'source': 14, 'target': 17, 'weight': 1.0},
#   {'source': 14, 'target': 18, 'weight': 1.0},
#   {'source': 14, 'target': 19, 'weight': 1.0},
#   {'source': 15, 'target': 16, 'weight': 1.0},
#   {'source': 15, 'target': 17, 'weight': 1.0},
#   {'source': 15, 'target': 18, 'weight': 1.0},
#   {'source': 15, 'target': 19, 'weight': 1.0},
#   {'source': 16, 'target': 17, 'weight': 1.0},
#   {'source': 16, 'target': 18, 'weight': 1.0},
#   {'source': 16, 'target': 19, 'weight': 1.0},
#   {'source': 17, 'target': 18, 'weight': 1.0},
#   {'source': 17, 'target': 19, 'weight': 1.0},
#   {'source': 18, 'target': 19, 'weight': 1.0},
#   {'source': 20, 'target': 21, 'weight': 1.0},
#   {'source': 20, 'target': 22, 'weight': 1.0},
#   {'source': 20, 'target': 23, 'weight': 1.0},
#   {'source': 20, 'target': 24, 'weight': 1.0},
#   {'source': 20, 'target': 25, 'weight': 1.0},
#   {'source': 20, 'target': 26, 'weight': 1.0},
#   {'source': 20, 'target': 27, 'weight': 1.0},
#   {'source': 20, 'target': 28, 'weight': 1.0},
#   {'source': 20, 'target': 29, 'weight': 1.0},
#   {'source': 21, 'target': 22, 'weight': 1.0},
#   {'source': 21, 'target': 23, 'weight': 1.0},
#   {'source': 21, 'target': 24, 'weight': 1.0},
#   {'source': 21, 'target': 25, 'weight': 1.0},
#   {'source': 21, 'target': 26, 'weight': 1.0},
#   {'source': 21, 'target': 27, 'weight': 1.0},
#   {'source': 21, 'target': 28, 'weight': 1.0},
#   {'source': 21, 'target': 29, 'weight': 1.0},
#   {'source': 22, 'target': 23, 'weight': 1.0},
#   {'source': 22, 'target': 24, 'weight': 1.0},
#   {'source': 22, 'target': 25, 'weight': 1.0},
#   {'source': 22, 'target': 26, 'weight': 1.0},
#   {'source': 22, 'target': 27, 'weight': 1.0},
#   {'source': 22, 'target': 28, 'weight': 1.0},
#   {'source': 22, 'target': 29, 'weight': 1.0},
#   {'source': 23, 'target': 24, 'weight': 1.0},
#   {'source': 23, 'target': 25, 'weight': 1.0},
#   {'source': 23, 'target': 26, 'weight': 1.0},
#   {'source': 23, 'target': 27, 'weight': 1.0},
#   {'source': 23, 'target': 28, 'weight': 1.0},
#   {'source': 23, 'target': 29, 'weight': 1.0},
#   {'source': 24, 'target': 25, 'weight': 1.0},
#   {'source': 24, 'target': 26, 'weight': 1.0},
#   {'source': 24, 'target': 27, 'weight': 1.0},
#   {'source': 24, 'target': 28, 'weight': 1.0},
#   {'source': 24, 'target': 29, 'weight': 1.0},
#   {'source': 25, 'target': 26, 'weight': 1.0},
#   {'source': 25, 'target': 27, 'weight': 1.0},
#   {'source': 25, 'target': 28, 'weight': 1.0},
#   {'source': 25, 'target': 29, 'weight': 1.0},
#   {'source': 26, 'target': 27, 'weight': 1.0},
#   {'source': 26, 'target': 28, 'weight': 1.0},
#   {'source': 26, 'target': 29, 'weight': 1.0},
#   {'source': 27, 'target': 28, 'weight': 1.0},
#   {'source': 27, 'target': 29, 'weight': 1.0},
#   {'source': 28, 'target': 29, 'weight': 1.0},
#   {'source': 30, 'target': 31, 'weight': 1.0},
#   {'source': 30, 'target': 32, 'weight': 1.0},
#   {'source': 30, 'target': 33, 'weight': 1.0},
#   {'source': 30, 'target': 34, 'weight': 1.0},
#   {'source': 30, 'target': 35, 'weight': 1.0},
#   {'source': 30, 'target': 36, 'weight': 1.0},
#   {'source': 30, 'target': 37, 'weight': 1.0},
#   {'source': 30, 'target': 38, 'weight': 1.0},
#   {'source': 30, 'target': 39, 'weight': 1.0},
#   {'source': 30, 'target': 40, 'weight': 1.0},
#   {'source': 30, 'target': 41, 'weight': 1.0},
#   {'source': 30, 'target': 42, 'weight': 1.0},
#   {'source': 31, 'target': 32, 'weight': 1.0},
#   {'source': 31, 'target': 33, 'weight': 1.0},
#   {'source': 31, 'target': 34, 'weight': 1.0},
#   {'source': 31, 'target': 35, 'weight': 1.0},
#   {'source': 31, 'target': 36, 'weight': 1.0},
#   {'source': 31, 'target': 37, 'weight': 1.0},
#   {'source': 31, 'target': 38, 'weight': 1.0},
#   {'source': 31, 'target': 39, 'weight': 1.0},
#   {'source': 31, 'target': 40, 'weight': 1.0},
#   {'source': 31, 'target': 41, 'weight': 1.0},
#   {'source': 31, 'target': 42, 'weight': 1.0},
#   {'source': 32, 'target': 33, 'weight': 1.0},
#   {'source': 32, 'target': 34, 'weight': 1.0},
#   {'source': 32, 'target': 35, 'weight': 1.0},
#   {'source': 32, 'target': 36, 'weight': 1.0},
#   {'source': 32, 'target': 37, 'weight': 1.0},
#   {'source': 32, 'target': 38, 'weight': 1.0},
#   {'source': 32, 'target': 39, 'weight': 1.0},
#   {'source': 32, 'target': 40, 'weight': 1.0},
#   {'source': 32, 'target': 41, 'weight': 1.0},
#   {'source': 32, 'target': 42, 'weight': 1.0},
#   {'source': 33, 'target': 34, 'weight': 1.0},
#   {'source': 33, 'target': 35, 'weight': 1.0},
#   {'source': 33, 'target': 36, 'weight': 1.0},
#   {'source': 33, 'target': 37, 'weight': 1.0},
#   {'source': 33, 'target': 38, 'weight': 1.0},
#   {'source': 33, 'target': 39, 'weight': 1.0},
#   {'source': 33, 'target': 40, 'weight': 1.0},
#   {'source': 33, 'target': 41, 'weight': 1.0},
#   {'source': 33, 'target': 42, 'weight': 1.0},
#   {'source': 34, 'target': 35, 'weight': 1.0},
#   {'source': 34, 'target': 36, 'weight': 1.0},
#   {'source': 34, 'target': 37, 'weight': 1.0},
#   {'source': 34, 'target': 38, 'weight': 1.0},
#   {'source': 34, 'target': 39, 'weight': 1.0},
#   {'source': 34, 'target': 40, 'weight': 1.0},
#   {'source': 34, 'target': 41, 'weight': 1.0},
#   {'source': 34, 'target': 42, 'weight': 1.0},
#   {'source': 35, 'target': 36, 'weight': 1.0},
#   {'source': 35, 'target': 37, 'weight': 1.0},
#   {'source': 35, 'target': 38, 'weight': 1.0},
#   {'source': 35, 'target': 39, 'weight': 1.0},
#   {'source': 35, 'target': 40, 'weight': 1.0},
#   {'source': 35, 'target': 41, 'weight': 1.0},
#   {'source': 35, 'target': 42, 'weight': 1.0},
#   {'source': 36, 'target': 37, 'weight': 1.0},
#   {'source': 36, 'target': 38, 'weight': 1.0},
#   {'source': 36, 'target': 39, 'weight': 1.0},
#   {'source': 36, 'target': 40, 'weight': 1.0},
#   {'source': 36, 'target': 41, 'weight': 1.0},
#   {'source': 36, 'target': 42, 'weight': 1.0},
#   {'source': 37, 'target': 38, 'weight': 1.0},
#   {'source': 37, 'target': 39, 'weight': 1.0},
#   {'source': 37, 'target': 40, 'weight': 1.0},
#   {'source': 37, 'target': 41, 'weight': 1.0},
#   {'source': 37, 'target': 42, 'weight': 1.0},
#   {'source': 38, 'target': 39, 'weight': 1.0},
#   {'source': 38, 'target': 40, 'weight': 1.0},
#   {'source': 38, 'target': 41, 'weight': 1.0},
#   {'source': 38, 'target': 42, 'weight': 1.0},
#   {'source': 39, 'target': 40, 'weight': 1.0},
#   {'source': 39, 'target': 41, 'weight': 1.0},
#   {'source': 39, 'target': 42, 'weight': 1.0},
#   {'source': 40, 'target': 41, 'weight': 1.0},
#   {'source': 40, 'target': 42, 'weight': 1.0},
#   {'source': 41, 'target': 42, 'weight': 1.0}],
#  'nodes': [{'id': 1, 'name': 'Demokratie'},
#   {'id': 2, 'name': 'Plattform'},
#   {'id': 3, 'name': 'Telegram'},
#   {'id': 4, 'name': 'Risiko'},
#   {'id': 5, 'name': 'gesellschaftliche'},
#   {'id': 6, 'name': 'System'},
#   {'id': 7, 'name': 'Straftat'},
#   {'id': 8, 'name': 'Maxime'},
#   {'id': 9, 'name': 'Klicks'},
#   {'id': 10, 'name': 'groß'},
#   {'id': 11, 'name': 'werdende'},
#   {'id': 12, 'name': 'Datensammlungen'},
#   {'id': 13, 'name': 'Präsidentschaft'},
#   {'id': 14, 'name': 'Donald'},
#   {'id': 15, 'name': 'Trumps'},
#   {'id': 16, 'name': 'verbunden'},
#   {'id': 17, 'name': 'Ausführung'},
#   {'id': 18, 'name': 'Twitter'},
#   {'id': 19, 'name': 'Gefahr'},
#   {'id': 20, 'name': 'Bundesverfassungsgerichtsurteil'},
#   {'id': 21, 'name': '18.'},
#   {'id': 22, 'name': 'Juli'},
#   {'id': 23, 'name': 'öffentlich-rechtliche'},
#   {'id': 24, 'name': 'Rundfunk'},
#   {'id': 25, 'name': 'Wert'},
#   {'id': 26, 'name': 'freiheitlich'},
#   {'id': 27, 'name': 'Ausdruck'},
#   {'id': 28, 'name': 'aktuell'},
#   {'id': 29, 'name': 'Form'},
#   {'id': 30, 'name': 'enorme'},
#   {'id': 31, 'name': 'Bedrohung'},
#   {'id': 32, 'name': 'Informationsfreiheit'},
#   {'id': 33, 'name': 'marktbeherrschend'},
#   {'id': 34, 'name': 'globalistischen'},
#   {'id': 35, 'name': 'Plattformbetreiber'},
#   {'id': 36, 'name': 'eigene'},
#   {'id': 37, 'name': 'politische'},
#   {'id': 38, 'name': 'Agenda'},
#   {'id': 39, 'name': 'politisch'},
#   {'id': 40, 'name': 'ungewollt'},
#   {'id': 41, 'name': 'Meinungsäußerungen'},
#   {'id': 42, 'name': 'zunehmen'}]}

# %%
def GraphVisualizer(data, ncol, nlabel, darkmode, edgevisibility, particles):
    # evaluate the boolean arguments
    if edgevisibility == True:
        lv = "//"
    else:
        lv = ""
    if particles == False:
        parts = "//"
    else:
        parts = ""
    if darkmode == False:
        dm = "//"
    else:
        dm = ""
    
    d3graph = {"nodes": [], "links": []}
    d3graph["nodes"] = data["nodes"]
    d3graph["links"] = data["links"]

    htmlcode = f"""<head>
        <style> body {{margin: 0;}} </style>
        <script src="https://unpkg.com/force-graph"></script>
        <meta charset="UTF-8">
    </head>
    <body>
    <div id="graph"></div>
    <script>
        var data = {d3graph};
        const elem = document.getElementById('graph');
        const Graph = ForceGraph()(elem)
            .graphData(data)
            .nodeLabel('{nlabel}')
            .nodeAutoColorBy('{ncol}')
            {dm}.backgroundColor('#000000')
            {dm}.linkColor(() => 'rgba(255,255,255,0.2)')
            {lv}.linkVisibility('false')
            {parts}.linkDirectionalParticles(2)
            {parts}.linkDirectionalParticleWidth(1.4)
            .onNodeClick (node => {{window.open(`wordnet.html`, '_blank')}})
            //.onNodeHover(node => elem.style.cursor = node ? 'pointer' : null)
            .onNodeRightClick(node => {{
                // Center/zoom on node
                Graph.centerAt(node.x, node.y, 1000);
                Graph.zoom(8, 2000);
            }});
    </script>
    </body>
    """
    return {'graph':htmlcode}


# .onNodeClick (node => {{window.open(`https://www.universecity.de`, '_blank')}})

# %%
json = {'data':graph, 
        'nodecoloring':'party', 
        'nodelabel': 'name', 
        #'nodelabel': 'mfic',
        "darkmode": False,
        "edgevisibility": True,
        "particles": False
       }

htmlgraph = GraphVisualizer(graph,'name','name',True,True,True)

# %%
with open (f"./graph.html", "w") as f:
    f.write(htmlgraph['graph'])
