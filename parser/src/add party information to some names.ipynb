# %%
import jsonlines
import json

# %%
# works with the already preprocessed speeches. Change the name of the file accordingly

path = '../../data/'

legis_period = 19
speeches_are_preprocessed = False

# %%
if speeches_are_preprocessed:
    name_of_file = f'speeches_preprocessed_{legis_period}.json'
    # use this way to import preprocessed data
    with open(f"{path}{name_of_file}", 'r') as fp:
        data = json.load(fp)
    reden = data.copy()
else:
    name_of_file = f'speeches_{legis_period}.jsonl'
    #imports not yet preprocessed speeches
    reden = []
    with jsonlines.open(f'{path}{name_of_file}') as f:
        for line in f.iter():
            reden.append(line)
    reden.sort(key = lambda x:x['date'])

# %%
# bei manchen Redner*innen sind keine Parteiinformationen hinterlegt. Diese Fälle können hier (leider manuell)
# behandelt werden
for rede in reden:

    if rede['party'] == 'unknown':
        print(rede['name'])
    rede['party']=rede['party'].replace(u'\xa0', u' ')
    if rede['party']=='Bündnis 90/Die Grünen':
        rede['party']='BÜNDNIS 90/DIE GRÜNEN'
    if rede['party']=='Fraktionslos':
        rede['party']='fraktionslos'

    if rede['name'] == 'Dr. Dirk-UlrichLena Mende Kreck':
        rede['name'] = 'Lena Kreck'
        rede['party'] = 'DIE LINKE'
        rede['name'] = 'Alexander Föhr'
    if rede['name'] == 'Dirk-UlrichAlexander Mende Föhr':
        rede['name'] = 'Alexander Föhr'
        rede['party'] = 'CDU/CSU'
    if rede['name'] == 'Dr. Franziska Giffey':
        rede['name'] = 'Franziska Giffey'

    if rede['name'] == 'Anne Spiegel':
        rede['party'] = "SPD"
    if rede['name'] == 'Christine Lambrecht':
        rede['party'] = "SPD"
    if rede['name'] == 'Svenja Schulze':
        rede['party'] = "SPD"
    if rede['name'] == 'Klara Geywitz':
        rede['party'] = "SPD"
    if rede['name'] == 'Wolfgang Schmidt':
        rede['party'] = "SPD"
    if rede['name'] == 'Nancy Faeser':
        rede['party'] = "SPD"
    if rede['name'] == 'Clara Bünger':
        rede['party'] = "DIE LINKE"
    if rede['name'] == 'Dr. Joachim Pfeiffer':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Dr. Dietmar Bartsch':
        rede['party'] = "DIE LINKE"
    if rede['name'] == 'Dr. Eva Högl':
        rede['party'] = "DIE LINKE"
    if rede['name'] == 'Boris Pistorius':
        rede['party'] = "SPD"
    if rede['name'] == 'Sven Schulze':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Dr. Reiner':
        rede['party'] = "AfD"
    if rede['name'] == 'Peter Beuth':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Klaus Holetschek':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Daniel Rinkert':
        rede['party'] = "SPD"
    if rede['name'] == 'Anke Rehlinger':
        rede['party'] = "SPD"
    if rede['name'] == 'Bettina Jarasch':
        rede['party'] = 'BÜNDNIS 90/DIE GRÜNEN'
    if rede['name'] == 'Emily Vontz':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Dieter Romann':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Alexander Bartz':
        rede['party'] = "SPD"
    if rede['name'] == 'Nils Gründer':
        rede['party'] = "FDP"
    if rede['name'] == 'Michael Sacher':
        rede['party'] = "BÜNDNIS 90/DIE GRÜNEN"
    if rede['name'] == 'Melanie Bernstein':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Dr. Roman Poseck':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Dr. Joachim Stamp':
        rede['party'] = "FDP"
    if rede['name'] == 'Dr. Dietmar Woidke':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Andreas Bovenschulte':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Reiner Haseloff':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Andreas Pinkwart':
        rede['party'] = "FDP"
    if rede['name'] == 'Dr. Jörg Steinbach':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Daniela De Ridder':
        rede['party'] = "SPD"
    if rede['name'] == 'Olaf Scholz':
        rede['party'] = "SPD"
    if rede['name'] == 'Annegret Kramp-Karrenbauer':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Kristina Nordt':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Dr. Felix Klein':
        rede['party'] = "fraktionslos"
    if rede['name'] == 'Julia Klöckner':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Dr. Peter Tschentscher':
        rede['party'] = "SPD"
    if rede['name'] == 'Malu Dreyer':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Christopher Gohl':
        rede['party'] = "FDP"
    if rede['name'] == 'Armin Laschet':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Franziska Giffey':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Joe Weingarten':
        rede['party'] = "SPD"
    if rede['name'] == 'Sylvia Lehmann':
        rede['party'] = "SPD"
    if rede['name'] == 'Matthias Nölke':
        rede['party'] = "FDP"
    if rede['name'] == 'Dorothee Martin':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Janosch Dahmen':
        rede['party'] = "BÜNDNIS 90/DIE GRÜNEN"
    if rede['name'] == 'Horst Seehofer':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Georg Maier':
        rede['party'] = "SPD"
    if rede['name'] == 'Charlotte Schneidewind-Hartnagel':
        rede['party'] = "BÜNDNIS 90/DIE GRÜNEN"
    if rede['name'] == 'Maika Friemann-Jennert':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Bela Bach':
        rede['party'] = "SPD"
    if rede['name'] == 'Michael Kretschmer':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Dr. Saskia Ludwig':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Dr. Till Backhaus':
        rede['party'] = "SPD"
    if rede['name'] == 'Manuela Schwesig':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Volker Wissing':
        rede['party'] = "FDP"
    if rede['name'] == 'Sandra Bubendorfer-Licht':
        rede['party'] = "FDP"
    if rede['name'] == 'Georg Eisenreich':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Karl-Josef Laumann':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Jürgen Dusel':
        rede['party'] = "fraktionslos"
    if rede['name'] == 'Michael Müller':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Benjamin-Immanuel Hoff':
        rede['party'] = "DIE LINKE"
    if rede['name'] == 'Katja Meier':
        rede['party'] = "BÜNDNIS 90/DIE GRÜNEN"
    if rede['name'] == 'Peter Altmaier':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'François de Rugy':
        rede['party'] = "fraktionslos"
    if rede['name'] == 'Brigitte Zypries':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Ole Schröder':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Carsten Träger':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Maria Böhmer':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Olaf in der Beek':
        rede['party'] = "FDP"
    if rede['name'] == 'Dr. Hans-Peter Bartels':
        rede['party'] = "SPD"
    if rede['name'] == 'Verena Bentele':
        rede['party'] = "SPD"
    if rede['name'] == 'Marja-Liisa Völlers':
        rede['party'] = "SPD"
    if rede['name'] == 'Martin Dulig':
        rede['party'] = "SPD"
    if rede['name'] == 'Dr. Carsten Sieling, Bürgermeister':
        rede['party'] = "SPD"
    if rede['name'] == 'Gisela Manderla':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Andreas Geisel':
        rede['party'] = "SPD"
    if rede['name'] == 'Nina Warken':
        rede['party'] = "CDU/CSU"
    if rede['name'] == 'Elke Breitenbach':
        rede['party'] = "DIE LINKE"
    if rede['name'] == 'Christian Natterer':
        rede['party'] = "CDU/CSU"

# %%
if speeches_are_preprocessed:
    with open(f"{path}{name_of_file}", 'w') as fp:
        json.dump(reden, fp, sort_keys=True, indent=4)
else:
    with open(f"{path}{name_of_file}", 'w', encoding='utf-8') as f:
        for line in reden:
            json.dump(line, f, ensure_ascii=False)
            f.write('\n')
